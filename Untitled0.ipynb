# %% [markdown]
# <a href="https://colab.research.google.com/github/isabellyisidoro/Aula-de-P.A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World

# %%
# Tipos Numéricos
idade=14 # int

altura=1.60 # float

numerico_complexo = 2 + 3j # complex

# Tipo texto
nome = "Isabelly" # str

# Tipo Booleano
esta_chovendo = False # bool

# Tipo Lista (mutável)
numeros = [1, 2, 3, 4, 5] # List

# Tipo Tupla (imutável)
cordenadas = (10, 20) # tuple

# tipo conjunto (valores únicos)
vogais = {'a', 'e', 'i', 'o', 'u'}

# Tipo Dicionário (chave-valor)
pessoa = {"nome": "Carlo", "idade": 30} # dict
# Out:
# <>:18: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:18: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# /tmp/ipython-input-659/530063833.py:18: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   cordenadas = 9(10, 20) # set
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-659/530063833.py in <cell line: 0>()
#      16
#      17 # Tipo Tupla (imutável)
# ---> 18 cordenadas = 9(10, 20) # set
#      19
#      20 # tipo conjunto (valores únicos)
#
# TypeError: 'int' object is not callable
