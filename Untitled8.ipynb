# %% [markdown]
# <a href="https://colab.research.google.com/github/isabellyisidoro/Aula-de-P.A/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Cópia de Aula 22/05

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/11U_jw5di3ebdDQ0l8OP0w2KckaWBAzxR
"""

numero = 0
while numero < 5:
  print (numero)
  numero += 1

#senha simples
senha = ""
try:
  while senha != 1234:
   senha = int(input("Insira sua senha: "))
   if senha == 1234:

    print("acesso liberado")
except:
  print("A senha deve conter só números")

# contagem regressiva

contador = int(input("Insira um número "))

while contador >= 0:
  print(contador)
  contador -=1
print("Acabou")

# opçao1 = soma
# opçao2 = subtrair
# opçao3 = multiplicar
# opçao4 = divisão
# opçao5 = sair

print("soma = 1")
print("subtração = 2")
print("multiplcação = 3")
print("Divisão = 4")
print("sair = 5")
print("")

opçao = 0
numero1 = 0
numero2 = 0

while opçao != 5:
  opçao = int(input("digite uma opção de 1 a 4 ou 5 para sair: "))
  print("")

  if opçao == 1:
    numero1 = int(input("digite um número: "))
    print("")
    numero2 = int(input("digite um número: "))
    print("")
    print(f"A soma de {numero1} com {numero2} é igual à {(numero1 + numero2)}")
    print("")
  elif opçao == 2:
    numero1 = int(input("digite um número: "))
    print("")
    numero2 = int(input("digite um número: "))
    print("")
    print(f"A subtração de {numero1} com {numero2} é igual à {(numero1 - numero2)}")
    print("")
  elif opçao == 3:
    numero1 = int(input("digite um número: "))
    print("")
    numero2 = int(input("digite um número: "))
    print("")
    print(f"A Multiplicação de {numero1} com {numero2} é igual à {(numero1 * numero2)}")
    print("")
  elif opçao == 4:
    numero1 = int(input("digite um número: "))
    print("")
    numero2 = int(input("digite um número: "))
    print("")
    print(f"A divisão de {numero1} com {numero2} é igual à {(numero1 / numero2)}")
    print("")
  else:
    print("até mais")
    print("")

soma_notas = 0
contador = 1

while contador <= 4:
    nota = float(input(f"Digite a {contador}ª nota: "))
    soma_notas += nota
    contador += 1
media = soma_notas / 4
print(f"\nMédia do aluno: {media:.2f}")
if media >= 7.0:
    print("Você foi aprovado")
elif media >= 5.0:
    print("Você ficou de recuperação")
elif media < 0 or media > 10:
  print("Nota invalida")
else:
    print("Você foi reprovado")
