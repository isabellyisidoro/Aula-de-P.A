# %% [markdown]
# <a href="https://colab.research.google.com/github/isabellyisidoro/Aula-de-P.A/blob/main/aula_dia_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estrutura de decisões (if, elif e else)

# Escrever um programa que compara 02 números

# Entradas
a = int (input("Digite um número inteiro: "))
b = int (input("Digite um número inteiro: "))

#processamento / saída

if a == b:
 print (f"{a} é igual {b}")

else:
  print (f"{a} é diferente de {b}")
# Out:
# Digite um número inteiro: 13
# Digite um número inteiro: 7
# 13 é diferente de 7

# %%
# escrever um porgrama que verifica se o numero digitado é par ou impar

# Entrada

numero = int (input("digite um numero: "))

# Processamento / saída

if numero % 2 == 0:

  print (f" o numero {numero} é par")

else:

  print (f"o numero {numero} é impar")
# Out:
# digite um numero: 12
#  o numero 12 é par

# %%
#Escrever um programa que o usuario digita o nome e a idade e verifica se o usuaria é criança

#Entrada

nome = str (input("Digite o seu nome"))
idade = int (input("digite sua idade"))

#processamento / saida

if idade <12:
  print ("criança")

else:
  print ("adolecente")
# Out:
# Digite o seu nomeisabelly
# digite sua idade14
# adolecente

# %%
# Escrever um programa de uma calculadora simples. O usuaria íra digirar 02 numeros e escolhera uma operação aritimetica

#Entrada

print ("-----------CALCULADORA--------")
print ("                              ")
print ("------------menu--------------")
print ("                              ")
print ("Opção = 1 - Soma              ")
print ("Opção = 2 - subtração         ")
print ("Opção = 3 - Multiplicação     ")
print ("Opção = 4 - Divisão           ")
print ("------------------------------")

#Entrada
numero = float (input ("digite um numero: "))
opcao = int(input("escolha a opção desejada: "))
numero1 = float(input("digite um numero"))

#processamento / saida
if opcao == 1:
  print(f"A soma de {numero} e {numero1} é igual a {numero + numero1} :")

elif opcao == 2:
  print(f"A soma de {numero} e {numero1} é igual a {numero - numero1} :")

elif opcao == 3:
  print(f"A soma de {numero} e {numero1} é igual a {numero * numero1} :")

elif opcao == 4:
  print(f"A soma de {numero} e {numero1} é igual a {numero / numero1} :")



else:

  print ("opção invalida")
# Out:
# -----------CALCULADORA--------
#
# ------------menu--------------
#
# Opção = 1 - Soma
# Opção = 2 - subtração
# Opção = 3 - Multiplicação
# Opção = 4 - Divisão
# ------------------------------
# digite um numero: 12
# escolha a opção desejada:  3
# digite um numero4
# A soma de 12.0 e 4.0 é igual a 48.0 :
